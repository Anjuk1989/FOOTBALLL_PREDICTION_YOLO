# %%
# !unzip /content/Finalv1.v1i.yolov8.zip
# Out:
# Archive:  /content/Finalv1.v1i.yolov8.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/100_PNG.rf.cb6970ada3008a932c483c21b29e926a.jpg
#  extracting: test/images/10_PNG.rf.c78948b8e2fcb7b41af54fe82a26fca2.jpg
#  extracting: test/images/111_PNG.rf.2fceb09c9cf539febb743d0fbd631ce2.jpg
#  extracting: test/images/131_PNG.rf.b020504b180d1746d685ea291d77d8ad.jpg
#  extracting: test/images/136_PNG.rf.2669742f3cf2f97801991dc52be2fb4e.jpg
#  extracting: test/images/149_PNG.rf.b80ec777b9106c666a931bb413e9546c.jpg
#  extracting: test/images/15_PNG.rf.5949b32109ea23e6a2d087010fd1a3e9.jpg
#  extracting: test/images/15_PNG.rf.6bafc6e798417b9e4a912f9a561b358a.jpg
#  extracting: test/images/161_PNG.rf.e8ac6bd6c59aac9c8d431ce19d4f7f47.jpg
#  extracting: test/images/165_PNG.rf.f9da2c986680ee3a50355e41399089ce.jpg
# ...

# %%
# !pip install ultralytics

# %%
# !yolo task="detect" mode="train" model=yolov8l.pt data=/content/data.yaml epochs=10 project=/content/final_results
# Out:
# Ultralytics 8.3.161 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model=YOLO("/content/final_results/train3/weights/best.pt")

# %%
lst=model(["/content/Screenshot 2025-07-03 001310.png"])
lst[0].save("footballresult.jpg")
# Out:
# 0: 320x640 1 goalkeeper, 16 players, 2 referees, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 'footballresult.jpg'

# %%
! yolo task="detect" mode=predict model=/content/final_results/train3/weights/best.pt source="/content/Screen Recording 2025-07-02 233922.mp4" project=/content/predict_results
# Out:
# Ultralytics 8.3.161 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,609,692 parameters, 0 gradients, 164.8 GFLOPs
#
# video 1/1 (frame 1/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 5 players, 57.8ms
# video 1/1 (frame 2/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 5 players, 39.0ms
# video 1/1 (frame 3/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 4 players, 39.0ms
# video 1/1 (frame 4/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 6 players, 38.9ms
# video 1/1 (frame 5/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 8 players, 29.5ms
# video 1/1 (frame 6/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 6 players, 29.5ms
# video 1/1 (frame 7/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 6 players, 29.5ms
# video 1/1 (frame 8/955) /content/Screen Recording 2025-07-02 233922.mp4: 352x640 4 players, 29.5ms
# ...
